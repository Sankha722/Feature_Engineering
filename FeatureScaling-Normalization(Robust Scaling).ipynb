# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('SampleFile.csv')
df.head()
# Out:
#    LotArea  MSSubClass
# 0     8450          60
# 1     9600          20
# 2    11250          60
# 3     9550          70
# 4    14260          60

# %%
df.describe()
# Out:
#              LotArea   MSSubClass
# count    1460.000000  1460.000000
# mean    10516.828082    56.897260
# std      9981.264932    42.300571
# min      1300.000000    20.000000
# 25%      7553.500000    20.000000
# 50%      9478.500000    50.000000
# 75%     11601.500000    70.000000
# max    215245.000000   190.000000

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize = (10,4))
sns.scatterplot(df['LotArea'], ax=ax1)
sns.scatterplot(df['MSSubClass'], ax=ax2)
# Out:
# <Axes: ylabel='MSSubClass'>

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()

# %%
df_Scaled = scaler.fit_transform(df)

# %%
df_Scaled = pd.DataFrame(df_Scaled, columns=df.columns)

# %%
df_Scaled
# Out:
#        LotArea  MSSubClass
# 0    -0.254076         0.2
# 1     0.030015        -0.6
# 2     0.437624         0.2
# 3     0.017663         0.4
# 4     1.181201         0.2
# ...        ...         ...
# 1455 -0.385746         0.2
# 1456  0.913167        -0.6
# 1457 -0.107831         0.4
# 1458  0.058918        -0.6
# 1459  0.113266        -0.6
#
# [1460 rows x 2 columns]

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize = (10,4))
sns.scatterplot(df_Scaled['LotArea'], ax=ax1)
sns.scatterplot(df_Scaled['MSSubClass'], ax=ax2)
# Out:
# <Axes: ylabel='MSSubClass'>
